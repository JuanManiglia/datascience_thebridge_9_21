# %% [markdown]
# # Ex2 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
#
# ### Step 1. Import the necessary libraries

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %% [markdown]
# ### Step 5. How many team participated in the Euro2012?

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %% [markdown]
# ### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %%
euro12[(euro12['Goals'] > 6) & (euro12['Shooting Accuracy'] > 50)]
# Out:
#      Team  Goals  Shots on target  Shots off target  Shooting Accuracy  \
# 13  Spain     12               42                33               55.9
#
#     % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 13              16.0                         100             0              1
#
#     Penalties not scored  Headed goals  Passes  Passes completed  \
# 13                     0             2    4317              3820
#
#     Passing Accuracy  Touches  Crosses  Dribbles  Corners Taken  Tackles  \
# 13              88.4     5585       69       106             44      122
#
#     Clearances  Interceptions  Clearances off line  Clean Sheets  Blocks  \
# 13         102             79                  0.0             5       8
#
#     Goals conceded  Saves made  Saves-to-shots ratio  Fouls Won  \
# 13               1          15                  93.8        102
#
#     Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# ...

# %%
euro12[euro12['Goals'] == euro12['Goals'].min()][['Team']]
# Out:
#                    Team
# 11  Republic of Ireland

# %%
euro12[['Team']]
# Out:
#                    Team
# 0               Croatia
# 1        Czech Republic
# 2               Denmark
# 3               England
# 4                France
# 5               Germany
# 6                Greece
# 7                 Italy
# 8           Netherlands
# 9                Poland
# 10             Portugal
# 11  Republic of Ireland
# 12               Russia
# 13                Spain
# 14               Sweden
# 15              Ukraine

# %%
euro12[['Team', 'Goals']]
# Out:
#                    Team  Goals
# 0               Croatia      4
# 1        Czech Republic      4
# 2               Denmark      4
# 3               England      5
# 4                France      3
# 5               Germany     10
# 6                Greece      5
# 7                 Italy      6
# 8           Netherlands      2
# 9                Poland      2
# 10             Portugal      6
# 11  Republic of Ireland      1
# 12               Russia      5
# 13                Spain     12
# 14               Sweden      5
# 15              Ukraine      2

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
import pandas as pd

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv', sep=',')
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
# txt.split("#", 1) 
txt = "51.9%"
txt.split("%")
# Out:
# ['51.9', '']

# %%
euro12['Shooting Accuracy'].str.split('%')[0:10]
# Out:
# 0    [51.9, ]
# 1    [41.9, ]
# 2    [50.0, ]
# 3    [50.0, ]
# 4    [37.9, ]
# 5    [47.8, ]
# 6    [30.7, ]
# 7    [43.0, ]
# 8    [25.0, ]
# 9    [39.4, ]
# Name: Shooting Accuracy, dtype: object

# %%
euro12['Shooting Accuracy'].str.replace('%', '')
# Out:
# 0     51.9
# 1     41.9
# 2     50.0
# 3     50.0
# 4     37.9
# 5     47.8
# 6     30.7
# 7     43.0
# 8     25.0
# 9     39.4
# 10    34.3
# 11    36.8
# 12    22.5
# 13    55.9
# 14    47.2
# 15    21.2
# Name: Shooting Accuracy, dtype: object

# %%
euro12['Shooting Accuracy'] = pd.to_numeric(euro12['Shooting Accuracy'].str.replace('%', ''))
euro12['% Goals-to-shots'] = pd.to_numeric(euro12['% Goals-to-shots'].str.replace('%', ''))
euro12['Passing Accuracy'] = pd.to_numeric(euro12['Passing Accuracy'].str.replace('%', ''))
euro12['Saves-to-shots ratio'] = pd.to_numeric(euro12['Saves-to-shots ratio'].str.replace('%', ''))
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target  \
# 0         Croatia      4               13                12
# 1  Czech Republic      4               13                18
# 2         Denmark      4               10                10
# 3         England      5               11                18
# 4          France      3               22                24
#
#    Shooting Accuracy  % Goals-to-shots  Total shots (inc. Blocked)  \
# 0               51.9              16.0                          32
# 1               41.9              12.9                          39
# 2               50.0              20.0                          27
# 3               50.0              17.2                          40
# 4               37.9               6.5                          65
#
#    Hit Woodwork  Penalty goals  Penalties not scored  Headed goals  Passes  \
# 0             0              0                     0             2    1076
# ...

# %%
euro12.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
euro12.describe()
# Out:
#            Goals  Shots on target  Shots off target  Shooting Accuracy  \
# count  16.000000        16.000000         16.000000          16.000000
# mean    4.750000        17.125000         24.937500          39.718750
# std     2.886751        10.582218         10.680005          10.761426
# min     1.000000         7.000000         10.000000          21.200000
# 25%     2.750000         9.750000         18.000000          33.400000
# 50%     4.500000        13.000000         23.500000          40.650000
# 75%     5.250000        22.000000         32.250000          48.350000
# max    12.000000        42.000000         45.000000          55.900000
#
#        % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  \
# count         16.000000                   16.000000     16.000000
# mean          11.687500                   54.937500      1.250000
# std            5.411454                   26.065223      1.612452
# ...

# %%
euro12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     float64
#  5   % Goals-to-shots            16 non-null     float64
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
# ...

# %%
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro12.loc[[3, 7, 12],['Goals','Shooting Accuracy']]
# Out:
#     Goals  Shooting Accuracy
# 3       5               50.0
# 7       6               43.0
# 12      5               22.5

# %%
euro12.loc[euro12['Team'].isin(['England', 'Italy', 'Russia']),['Shooting Accuracy']]
# Out:
#     Shooting Accuracy
# 3                50.0
# 7                43.0
# 12               22.5

# %%
euro12 = euro12.set_index("Team")
euro12
# Out:
#                      Goals  Shots on target  Shots off target  \
# Team
# Croatia                  4               13                12
# Czech Republic           4               13                18
# Denmark                  4               10                10
# England                  5               11                18
# France                   3               22                24
# Germany                 10               32                32
# Greece                   5                8                18
# Italy                    6               34                45
# Netherlands              2               12                36
# Poland                   2               15                23
# Portugal                 6               22                42
# Republic of Ireland      1                7                12
# Russia                   5                9                31
# Spain                   12               42                33
# ...

# %%
euro12.loc[['England', 'Italy', 'Russia'],['Shooting Accuracy']]
# Out:
#          Shooting Accuracy
# Team
# England               50.0
# Italy                 43.0
# Russia                22.5
