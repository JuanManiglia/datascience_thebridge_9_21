# %% [markdown]
# # Ex - GroupBy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
drinks[drinks['beer_servings'] == drinks['beer_servings'].max()]
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 117  Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8        AF

# %%
drinks['continent'].unique()
# Out:
# array(['AS', 'EU', 'AF', nan, 'SA', 'OC'], dtype=object)

# %%
len(drinks['country'].unique())

# %%
drinks.groupby(['continent'])['beer_servings'].mean().idxmax()
# Out:
# 'EU'

# %%
drinks.groupby(['continent'])['beer_servings'].mean().idxmax()
# Out:
# 'EU'

# %%
drinks.groupby(['continent'])['beer_servings'].mean().loc['EU']
# Out:
# 193.77777777777777

# %%
df_grouped = drinks.groupby(['continent'], as_index=False).mean()
df_grouped
# Out:
#   continent  beer_servings  spirit_servings  wine_servings  \
# 0        AF      61.471698        16.339623      16.264151
# 1        AS      37.045455        60.840909       9.068182
# 2        EU     193.777778       132.555556     142.222222
# 3        OC      89.687500        58.437500      35.625000
# 4        SA     175.083333       114.750000      62.416667
#
#    total_litres_of_pure_alcohol
# 0                      3.007547
# 1                      2.170455
# 2                      8.617778
# 3                      3.381250
# 4                      6.308333

# %%
df_grouped[df_grouped['beer_servings'] == df_grouped['beer_servings'].max()][['continent','beer_servings']]
# Out:
#   continent  beer_servings
# 2        EU     193.777778

# %%
drinks[drinks['continent'].isna()]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...

# %%
drinks['continent_fixed'] = np.where(drinks['continent'].isna(),'NorteAmerica', drinks['continent'])
# drinks['continent_fixed'] = np.where(drinks['continent_fixed']=='NorteAmerica', 'NA' , drinks['continent'])
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent continent_fixed
# 0                           0.0        AS              AS
# 1                           4.9        EU              EU
# 2                           0.7        AF              AF
# 3                          12.4        EU              EU
# 4                           5.9        AF              AF

# %%
drinks[drinks['continent_fixed']=='NA']
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
drinks.groupby(['continent_fixed'], as_index=False)[['wine_servings']].mean()
# Out:
#   continent_fixed  wine_servings
# 0              AF      16.264151
# 1              AS       9.068182
# 2              EU     142.222222
# 3    NorteAmerica      24.521739
# 4              OC      35.625000
# 5              SA      62.416667

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
drinks.groupby(['continent_fixed']).mean()
# Out:
#                  beer_servings  spirit_servings  wine_servings  \
# continent_fixed
# AF                   61.471698        16.339623      16.264151
# AS                   37.045455        60.840909       9.068182
# EU                  193.777778       132.555556     142.222222
# NorteAmerica        145.434783       165.739130      24.521739
# OC                   89.687500        58.437500      35.625000
# SA                  175.083333       114.750000      62.416667
#
#                  total_litres_of_pure_alcohol
# continent_fixed
# AF                                   3.007547
# AS                                   2.170455
# EU                                   8.617778
# NorteAmerica                         5.995652
# OC                                   3.381250
# SA                                   6.308333

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
drinks.groupby('continent').median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
drinks.groupby('continent')['spirit_servings'].mean()
# Out:
# continent
# AF     16.339623
# AS     60.840909
# EU    132.555556
# OC     58.437500
# SA    114.750000
# Name: spirit_servings, dtype: float64

# %%
drinks.groupby('continent')['spirit_servings'].min()
# Out:
# continent
# AF     0
# AS     0
# EU     0
# OC     0
# SA    25
# Name: spirit_servings, dtype: int64

# %%
drinks.groupby('continent')['spirit_servings'].max()
# Out:
# continent
# AF    152
# AS    326
# EU    373
# OC    254
# SA    302
# Name: spirit_servings, dtype: int64

# %%
drinks.groupby('continent')['spirit_servings'].agg(['mean', 'min', 'max'])
# Out:
#                  mean  min  max
# continent
# AF          16.339623    0  152
# AS          60.840909    0  326
# EU         132.555556    0  373
# OC          58.437500    0  254
# SA         114.750000   25  302

# %%
drinks[drinks['spirit_servings'] == drinks['spirit_servings'].min()]
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 0          Afghanistan              0                0              0
# 2              Algeria             25                0             14
# 13          Bangladesh              0                0              0
# 19              Bhutan             23                0              0
# 27             Burundi             88                0              0
# 46         North Korea              0                0              0
# 55   Equatorial Guinea             92                0            233
# 56             Eritrea             18                0              0
# 63              Gambia              8                0              1
# 70              Guinea              9                0              2
# 79                Iran              0                0              0
# 90              Kuwait              0                0              0
# ...

# %%
drinks[drinks['spirit_servings'] == drinks['spirit_servings'].max()]
# Out:
#     country  beer_servings  spirit_servings  wine_servings  \
# 68  Grenada            199              438             28
#
#     total_litres_of_pure_alcohol continent continent_fixed
# 68                          11.9       NaN    NorteAmerica

# %%
drinks[drinks['spirit_servings'] == drinks['spirit_servings'].mode()[0]]
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 0          Afghanistan              0                0              0
# 2              Algeria             25                0             14
# 13          Bangladesh              0                0              0
# 19              Bhutan             23                0              0
# 27             Burundi             88                0              0
# 46         North Korea              0                0              0
# 55   Equatorial Guinea             92                0            233
# 56             Eritrea             18                0              0
# 63              Gambia              8                0              1
# 70              Guinea              9                0              2
# 79                Iran              0                0              0
# 90              Kuwait              0                0              0
# ...

# %%
type(drinks['total_litres_of_pure_alcohol'].mode()[0])
# Out:
# numpy.float64

# %%
drinks.sort_values(by=['beer_servings'], ascending = False).head(10)[['country','beer_servings']]
# Out:
#             country  beer_servings
# 117         Namibia            376
# 45   Czech Republic            361
# 62            Gabon            347
# 65          Germany            346
# 98        Lithuania            343
# 135          Poland            343
# 188       Venezuela            333
# 81          Ireland            313
# 129           Palau            306
# 140         Romania            297

# %%
drinks.sort_values(by=['beer_servings']).tail(10)
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 140         Romania            297              122            167
# 129           Palau            306               63             23
# 81          Ireland            313              118            165
# 188       Venezuela            333              100              3
# 98        Lithuania            343              244             56
# 135          Poland            343              215             56
# 65          Germany            346              117            175
# 62            Gabon            347               98             59
# 45   Czech Republic            361              170            134
# 117         Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent continent_fixed
# 140                          10.4        EU              EU
# 129                           6.9        OC              OC
# ...

# %%
drinks.groupby(['continent_fixed','country']).sum()
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# continent_fixed country
# AF              Algeria                  25                0             14
#                 Angola                  217               57             45
#                 Benin                    34                4             13
#                 Botswana                173               35             35
#                 Burkina Faso             25                7              7
# ...                                     ...              ...            ...
# SA              Paraguay                213              117             74
#                 Peru                    163              160             21
#                 Suriname                128              178              7
#                 Uruguay                 115               35            220
#                 Venezuela               333              100              3
#
# ...
